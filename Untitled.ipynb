# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))

# %%
data = pd.read_csv('../input/patches.csv')
data.sample(n=5)
# Out:
#                p       p.1       p.2       p.3  class
# 202396  0.016750  0.016191  0.033016  0.031342      0
# 35002   0.511021  0.511021  0.517725  0.521647      0
# 186399  0.000000  0.000000  0.000000  0.000000      0
# 166485  0.346747  0.346747  0.350363  0.358206      0
# 277533  0.029400  0.029400  0.029400  0.025479      0

# %%
sns.pairplot( data=data, vars=('p','p.1','p.2','p.3'), hue='class' )
